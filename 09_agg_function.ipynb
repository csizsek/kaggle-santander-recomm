# %%
import base64
import datetime
import time
import json
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sns
import statsmodels as sm
from pylab import rcParams
from numpy import median
import matplotlib.dates as mdates

np.random.seed(1337)
# %matplotlib inline
sns.set(font_scale=1.5)
rcParams['figure.figsize'] = 12, 8
sns.set_style('whitegrid')
sns.set_palette(sns.color_palette('muted'))

# %%
def group_to_features(g, target):
    g = g.copy().sort_values('measurement_date')

    d = {}

    d['customer_id'] = g.customer_id.max()
    d['target'] = target

    last_id = g.index.tolist()[-1]
    for p in g.columns[23:]:
        g.set_value(last_id, p, np.nan)

    try:
        d['measurement_month_last'] = g.measurement_date.max().month
    except:
        d['measurement_month_last'] = np.nan

    d['gender'] = g.gender.max()
    d['age'] = g.age.max()

    try:
        d['first_contract_month'] = g.first_contract_date.max().month
    except:
        d['first_contract_month'] = np.nan

    try:
        d['age_at_first_contract'] = g.age.max() - (2016 - g.first_contract_date.max().year)
    except:
        d['age_at_first_contract'] = np.nan

    try:
        d['diff_first_contract_month_and_last_month'] = (g.first_contract_date.max().month - g.measurement_date.max().month) % 12
    except:
        d['diff_first_contract_month_and_last_month'] = np.nan

    try:
        d['first_contract_months_ago'] = (g.measurement_date.max() - g.first_contract_date.max()).days / 30
    except:
        d['first_contract_months_ago'] = np.nan

    d['customer_for_months'] = g.customer_for_months.max()

    try:
        d['diff_first_customer_month_and_last_month'] = (g.measurement_date.max().month - g.customer_for_months.max()) % 12
    except:
        d['diff_first_customer_month_and_last_month'] = np.nan

    try:
        d['diff_first_customer_month_and_first_contract_month'] = (g.first_contract_date.max().month - g.customer_for_months.max()) % 12
    except:
        d['diff_first_customer_month_and_first_contract_month'] = np.nan

    d['is_foreigner'] = g.is_foreigner.max()
    d['join_channel'] = g.join_channel.max()
    d['is_dead'] = np.nan
    if len(g.is_dead.dropna().tolist()) > 0:
        d['is_dead'] = g.is_dead.dropna().tolist()[-1]

    try:
        d['household_income_diff'] = g['household_income'].tolist()[-1] - g['household_income'].tolist()[0]
    except:
        d['household_income_diff'] = np.nan

    lca_features = [
        'employment_index',
        'country_of_residence',
        'is_new_customer',
        'is_primary_customer',
        'customer_type',
        'customer_relation_type',
        'country_residence_bank_same',
        'is_spouse_of_an_employee',
        'province_code',
        'is_active_customer',
        'household_income',
        'customer_segment']

    for p in g.columns[23:]:
        lca_features.append(p)
        d[p + '_sum'] = g[p].sum()

    for f in lca_features:
        try:
            d[f + '_last'] = g[f].dropna().tolist()[-1]
        except:
            d[f + '_last'] = np.nan

        d[f + '_changed'] = 'yes' if len(g[f].dropna().value_counts()) > 1 else 'no'
        d[f + '_changed_measurements_ago'] = np.nan
        if d[f + '_changed'] == 'yes':
            i = 2
            while len(g[f].dropna().tail(i).value_counts()) == 1:
                i += 1
            d[f + '_changed_measurements_ago'] = i - 1

    return d

# %%
dg = pd.read_csv('tmp/raw_train_ind_viv_fin_ult1.csv', parse_dates=['measurement_date', 'first_contract_date']).groupby(['customer_id'])

# %%
for k, g in dg:
    print k
# Out:
# 22225
# 45263
# 47386
# 49128
# 51089
# 58273
# 62001
# 72202
# 85015
# 86882
# 92988
# 101030
# 110092
# 114525
# 114534
# 116719
# 122718
# 125258
# 127156
# 135753
# 137923
# 157493
# 172361
# 182143
# 188618
# 199224
# 203032
# 211592
# 212806
# 215604
# 219222
# 233612
# 247509
# 250709
# 255674
# 261331
# 271897
# 277257
# 277945
# 283256
# 285221
# 286596
# 286725
# 287808
# 309386
# 312953
# 313750
# 316206
# 344758
# 345919
# 365101
# 386530
# 390129
# 395013
# 411469
# 416006
# 417379
# 418412
# 438707
# 448790
# 458204
# 462421
# 473873
# 476088
# 477198
# 490688
# 491165
# 511225
# 516799
# 522476
# 526809
# 546100
# 548296
# 571148
# 582638
# 584109
# 588885
# 604163
# 608668
# 614659
# 614763
# 622143
# 625279
# 629025
# 633379
# 644068
# 649223
# 653807
# 660345
# 664591
# 664664
# 669366
# 676467
# 677964
# 685808
# 690911
# 695702
# 708162
# 712616
# 716319
# 728688
# 733473
# 734055
# 734874
# 734932
# 757179
# 762318
# 780763
# 784320
# 784774
# 800104
# 819543
# 820535
# 831947
# 887040
# 887182
# 887394
# 888829
# 890419
# 910826
# 940826
# 952084
# 959075
# 967629
# 976556
# 997002
# 1008028
# 1011980
# 1016567
# 1022088
# 1022377
# 1027729
# 1045975
# 1055009
# 1061276
# 1065405
# 1073234
# 1073442
# 1074471
# 1077485
# 1080892
# 1084674
# 1085075
# 1099296
# 1108211
# 1109619
# 1139042
# 1149439
# 1160199
# 1163030
# 1164568
# 1167768
# 1181919
# 1185779
# 1192992
# 1198198
# 1199243
# 1210921
# 1211484
# 1213640
# 1217314
# 1219779
# 1220708
# 1222223
# 1222828
# 1222845
# 1227787
# 1247146
# 1273237
# 1273555
# 1292815
# 1304603
# 1312744
# 1312945
# 1321893
# 1328671
# 1328724
# 1332445
# 1342450
# 1350530
# 1363052
# 1363197
# 1364864
# 1383408
# 1392820
# 1395317
# 1396933
# 1405969
# 1417217
# 1420734
# 1445281
# 1446806
# 1461704
# 1464311
# 1480212
# 1481347
# 1488027
# 1500806
# 1508163
# 1508643
# 1516981
# 1527329
# 1545330
# 1549219

# %%
g = dg.get_group(1396933)
g.T
# Out:
#                                             2023                 2024  \
# customer_id                              1396933              1396933
# measurement_date             2015-06-28 00:00:00  2015-07-28 00:00:00
# employment_index                    not-employee         not-employee
# country_of_residence                          ES                   ES
# gender                                    female               female
# age                                           25                   25
# first_contract_date          2015-05-13 00:00:00  2015-05-13 00:00:00
# is_new_customer                              yes                  yes
# customer_for_months                            2                    2
# is_primary_customer                          yes                  yes
# last_primary_customer_date                   NaN                  NaN
# customer_type                            primary              primary
# customer_relation_type                    active               active
# country_residence_bank_same                  yes                  yes
# is_foreigner                                  no                   no
# is_spouse_of_an_employee                     NaN                  NaN
# join_channel                                 KHK                  KHK
# is_dead                                       no                   no
# address_type                             address              address
# province_code                            prov_28              prov_28
# is_active_customer                           yes                  yes
# household_income                          311274               311274
# customer_segment                      individual           individual
# ind_ahor_fin_ult1                              0                    0
# ind_aval_fin_ult1                              0                    0
# ind_cco_fin_ult1                               1                    1
# ind_cder_fin_ult1                              0                    0
# ind_cno_fin_ult1                               0                    0
# ind_ctju_fin_ult1                              0                    0
# ind_ctma_fin_ult1                              0                    0
# ind_ctop_fin_ult1                              0                    0
# ind_ctpp_fin_ult1                              0                    0
# ind_deco_fin_ult1                              0                    0
# ind_deme_fin_ult1                              0                    0
# ind_dela_fin_ult1                              0                    0
# ind_ecue_fin_ult1                              0                    0
# ind_fond_fin_ult1                              0                    0
# ind_hip_fin_ult1                               0                    0
# ind_plan_fin_ult1                              0                    0
# ind_pres_fin_ult1                              0                    0
# ind_reca_fin_ult1                              0                    0
# ind_tjcr_fin_ult1                              0                    0
# ind_valo_fin_ult1                              0                    0
# ind_viv_fin_ult1                               0                    0
# ind_nomina_ult1                                0                    0
# ind_nom_pens_ult1                              0                    0
# ind_recibo_ult1                                0                    0
#
#                                             2025                 2026  \
# customer_id                              1396933              1396933
# measurement_date             2015-08-28 00:00:00  2015-09-28 00:00:00
# employment_index                    not-employee         not-employee
# country_of_residence                          ES                   ES
# gender                                    female               female
# age                                           25                   25
# first_contract_date          2015-05-13 00:00:00  2015-05-13 00:00:00
# is_new_customer                              yes                  yes
# customer_for_months                            3                    4
# is_primary_customer                          yes                  yes
# last_primary_customer_date                   NaN                  NaN
# customer_type                            primary              primary
# customer_relation_type                    active               active
# country_residence_bank_same                  yes                  yes
# is_foreigner                                  no                   no
# is_spouse_of_an_employee                     NaN                  NaN
# join_channel                                 KHK                  KHK
# is_dead                                       no                   no
# address_type                             address              address
# province_code                            prov_28              prov_28
# is_active_customer                           yes                  yes
# household_income                          311274               311274
# customer_segment                      individual           individual
# ind_ahor_fin_ult1                              0                    0
# ind_aval_fin_ult1                              0                    0
# ind_cco_fin_ult1                               1                    1
# ind_cder_fin_ult1                              0                    0
# ind_cno_fin_ult1                               0                    0
# ind_ctju_fin_ult1                              0                    0
# ind_ctma_fin_ult1                              1                    1
# ind_ctop_fin_ult1                              0                    0
# ind_ctpp_fin_ult1                              0                    0
# ind_deco_fin_ult1                              0                    0
# ind_deme_fin_ult1                              0                    0
# ind_dela_fin_ult1                              0                    0
# ind_ecue_fin_ult1                              0                    0
# ind_fond_fin_ult1                              0                    0
# ind_hip_fin_ult1                               0                    0
# ind_plan_fin_ult1                              0                    0
# ind_pres_fin_ult1                              0                    0
# ind_reca_fin_ult1                              0                    0
# ind_tjcr_fin_ult1                              0                    0
# ind_valo_fin_ult1                              0                    0
# ind_viv_fin_ult1                               0                    0
# ind_nomina_ult1                                0                    0
# ind_nom_pens_ult1                              0                    0
# ind_recibo_ult1                                0                    0
#
#                                             2027                 2028  \
# customer_id                              1396933              1396933
# measurement_date             2015-10-28 00:00:00  2015-11-28 00:00:00
# employment_index                    not-employee         not-employee
# country_of_residence                          ES                   ES
# gender                                    female               female
# age                                           25                   25
# first_contract_date          2015-05-13 00:00:00  2015-05-13 00:00:00
# is_new_customer                              yes                   no
# customer_for_months                            5                    6
# is_primary_customer                          yes                  yes
# last_primary_customer_date                   NaN                  NaN
# customer_type                            primary              primary
# customer_relation_type                    active               active
# country_residence_bank_same                  yes                  yes
# is_foreigner                                  no                   no
# is_spouse_of_an_employee                     NaN                  NaN
# join_channel                                 KHK                  KHK
# is_dead                                       no                   no
# address_type                             address              address
# province_code                            prov_28              prov_28
# is_active_customer                           yes                  yes
# household_income                          311274               311274
# customer_segment                      individual           individual
# ind_ahor_fin_ult1                              0                    0
# ind_aval_fin_ult1                              0                    0
# ind_cco_fin_ult1                               1                    1
# ind_cder_fin_ult1                              0                    0
# ind_cno_fin_ult1                               0                    0
# ind_ctju_fin_ult1                              0                    0
# ind_ctma_fin_ult1                              0                    0
# ind_ctop_fin_ult1                              0                    0
# ind_ctpp_fin_ult1                              0                    0
# ind_deco_fin_ult1                              0                    0
# ind_deme_fin_ult1                              0                    0
# ind_dela_fin_ult1                              0                    0
# ind_ecue_fin_ult1                              1                    1
# ind_fond_fin_ult1                              0                    0
# ind_hip_fin_ult1                               0                    0
# ind_plan_fin_ult1                              0                    0
# ind_pres_fin_ult1                              0                    0
# ind_reca_fin_ult1                              0                    0
# ind_tjcr_fin_ult1                              0                    0
# ind_valo_fin_ult1                              0                    0
# ind_viv_fin_ult1                               0                    0
# ind_nomina_ult1                                0                    0
# ind_nom_pens_ult1                              0                    0
# ind_recibo_ult1                                0                    0
#
#                                             2029                 2030  \
# customer_id                              1396933              1396933
# measurement_date             2015-12-28 00:00:00  2016-01-28 00:00:00
# employment_index                    not-employee         not-employee
# country_of_residence                          ES                   ES
# gender                                    female               female
# age                                           25                   25
# first_contract_date          2015-05-13 00:00:00  2015-05-13 00:00:00
# is_new_customer                               no                   no
# customer_for_months                            7                    8
# is_primary_customer                          yes                  yes
# last_primary_customer_date                   NaN                  NaN
# customer_type                            primary              primary
# customer_relation_type                    active               active
# country_residence_bank_same                  yes                  yes
# is_foreigner                                  no                   no
# is_spouse_of_an_employee                     NaN                  NaN
# join_channel                                 KHK                  KHK
# is_dead                                       no                   no
# address_type                             address              address
# province_code                            prov_28              prov_28
# is_active_customer                           yes                  yes
# household_income                          311274               311274
# customer_segment                      individual           individual
# ind_ahor_fin_ult1                              0                    0
# ind_aval_fin_ult1                              0                    0
# ind_cco_fin_ult1                               1                    1
# ind_cder_fin_ult1                              0                    0
# ind_cno_fin_ult1                               0                    0
# ind_ctju_fin_ult1                              0                    0
# ind_ctma_fin_ult1                              0                    0
# ind_ctop_fin_ult1                              0                    0
# ind_ctpp_fin_ult1                              0                    0
# ind_deco_fin_ult1                              0                    0
# ind_deme_fin_ult1                              0                    0
# ind_dela_fin_ult1                              0                    0
# ind_ecue_fin_ult1                              1                    1
# ind_fond_fin_ult1                              0                    0
# ind_hip_fin_ult1                               0                    0
# ind_plan_fin_ult1                              0                    0
# ind_pres_fin_ult1                              0                    0
# ind_reca_fin_ult1                              0                    0
# ind_tjcr_fin_ult1                              0                    0
# ind_valo_fin_ult1                              0                    0
# ind_viv_fin_ult1                               0                    0
# ind_nomina_ult1                                0                    0
# ind_nom_pens_ult1                              0                    0
# ind_recibo_ult1                                0                    0
#
#                                             2031                 2032  \
# customer_id                              1396933              1396933
# measurement_date             2016-02-28 00:00:00  2016-03-28 00:00:00
# employment_index                    not-employee         not-employee
# country_of_residence                          ES                   ES
# gender                                    female               female
# age                                           25                   26
# first_contract_date          2015-05-13 00:00:00  2015-05-13 00:00:00
# is_new_customer                               no                   no
# customer_for_months                            9                   10
# is_primary_customer                          yes                  yes
# last_primary_customer_date                   NaN                  NaN
# customer_type                            primary              primary
# customer_relation_type                    active               active
# country_residence_bank_same                  yes                  yes
# is_foreigner                                  no                   no
# is_spouse_of_an_employee                     NaN                  NaN
# join_channel                                 KHK                  KHK
# is_dead                                       no                   no
# address_type                             address              address
# province_code                            prov_28              prov_28
# is_active_customer                           yes                  yes
# household_income                          311274               311274
# customer_segment                      individual           individual
# ind_ahor_fin_ult1                              0                    0
# ind_aval_fin_ult1                              0                    0
# ind_cco_fin_ult1                               1                    1
# ind_cder_fin_ult1                              0                    0
# ind_cno_fin_ult1                               0                    0
# ind_ctju_fin_ult1                              0                    0
# ind_ctma_fin_ult1                              0                    0
# ind_ctop_fin_ult1                              0                    0
# ind_ctpp_fin_ult1                              0                    0
# ind_deco_fin_ult1                              0                    0
# ind_deme_fin_ult1                              0                    0
# ind_dela_fin_ult1                              0                    0
# ind_ecue_fin_ult1                              1                    1
# ind_fond_fin_ult1                              0                    0
# ind_hip_fin_ult1                               0                    0
# ind_plan_fin_ult1                              0                    0
# ind_pres_fin_ult1                              0                    0
# ind_reca_fin_ult1                              0                    0
# ind_tjcr_fin_ult1                              0                    0
# ind_valo_fin_ult1                              0                    0
# ind_viv_fin_ult1                               0                    0
# ind_nomina_ult1                                0                    0
# ind_nom_pens_ult1                              0                    0
# ind_recibo_ult1                                0                    0
#
#                                             2033                 2034  \
# customer_id                              1396933              1396933
# measurement_date             2016-04-28 00:00:00  2016-05-28 00:00:00
# employment_index                    not-employee         not-employee
# country_of_residence                          ES                   ES
# gender                                    female               female
# age                                           26                   26
# first_contract_date          2015-05-13 00:00:00  2015-05-13 00:00:00
# is_new_customer                               no                   no
# customer_for_months                           11                   12
# is_primary_customer                          yes                  yes
# last_primary_customer_date                   NaN                  NaN
# customer_type                            primary              primary
# customer_relation_type                    active               active
# country_residence_bank_same                  yes                  yes
# is_foreigner                                  no                   no
# is_spouse_of_an_employee                     NaN                  NaN
# join_channel                                 KHK                  KHK
# is_dead                                       no                   no
# address_type                             address              address
# province_code                            prov_28              prov_28
# is_active_customer                           yes                  yes
# household_income                          311274               311274
# customer_segment                      individual           individual
# ind_ahor_fin_ult1                              0                    0
# ind_aval_fin_ult1                              0                    0
# ind_cco_fin_ult1                               1                    1
# ind_cder_fin_ult1                              0                    0
# ind_cno_fin_ult1                               0                    0
# ind_ctju_fin_ult1                              0                    0
# ind_ctma_fin_ult1                              0                    0
# ind_ctop_fin_ult1                              0                    0
# ind_ctpp_fin_ult1                              0                    0
# ind_deco_fin_ult1                              0                    0
# ind_deme_fin_ult1                              0                    0
# ind_dela_fin_ult1                              0                    0
# ind_ecue_fin_ult1                              1                    1
# ind_fond_fin_ult1                              0                    0
# ind_hip_fin_ult1                               0                    0
# ind_plan_fin_ult1                              0                    0
# ind_pres_fin_ult1                              0                    0
# ind_reca_fin_ult1                              0                    0
# ind_tjcr_fin_ult1                              0                    0
# ind_valo_fin_ult1                              0                    0
# ind_viv_fin_ult1                               0                    0
# ind_nomina_ult1                                0                    0
# ind_nom_pens_ult1                              0                    0
# ind_recibo_ult1                                0                    0
#
#                                             2035
# customer_id                              1396933
# measurement_date             2016-06-28 00:00:00
# employment_index                    not-employee
# country_of_residence                          ES
# gender                                    female
# age                                           26
# first_contract_date          2015-05-13 00:00:00
# is_new_customer                               no
# customer_for_months                           13
# is_primary_customer                          yes
# last_primary_customer_date                   NaN
# customer_type                            primary
# customer_relation_type                    active
# country_residence_bank_same                  yes
# is_foreigner                                  no
# is_spouse_of_an_employee                     NaN
# join_channel                                 KHK
# is_dead                                       no
# address_type                             address
# province_code                            prov_28
# is_active_customer                           yes
# household_income                          311274
# customer_segment                      individual
# ind_ahor_fin_ult1                            NaN
# ind_aval_fin_ult1                            NaN
# ind_cco_fin_ult1                             NaN
# ind_cder_fin_ult1                            NaN
# ind_cno_fin_ult1                             NaN
# ind_ctju_fin_ult1                            NaN
# ind_ctma_fin_ult1                            NaN
# ind_ctop_fin_ult1                            NaN
# ind_ctpp_fin_ult1                            NaN
# ind_deco_fin_ult1                            NaN
# ind_deme_fin_ult1                            NaN
# ind_dela_fin_ult1                            NaN
# ind_ecue_fin_ult1                            NaN
# ind_fond_fin_ult1                            NaN
# ind_hip_fin_ult1                             NaN
# ind_plan_fin_ult1                            NaN
# ind_pres_fin_ult1                            NaN
# ind_reca_fin_ult1                            NaN
# ind_tjcr_fin_ult1                            NaN
# ind_valo_fin_ult1                            NaN
# ind_viv_fin_ult1                             NaN
# ind_nomina_ult1                              NaN
# ind_nom_pens_ult1                            NaN
# ind_recibo_ult1                              NaN

# %%
group_to_features(g.head(1), np.nan)
# Out:
# {'age': 25.0,
#  'age_at_first_contract': 24.0,
#  'country_of_residence_changed': 'no',
#  'country_of_residence_changed_measurements_ago': nan,
#  'country_of_residence_last': 'ES',
#  'country_residence_bank_same_changed': 'no',
#  'country_residence_bank_same_changed_measurements_ago': nan,
#  'country_residence_bank_same_last': 'yes',
#  'customer_for_months': 2.0,
#  'customer_id': 1396933,
#  'customer_relation_type_changed': 'no',
#  'customer_relation_type_changed_measurements_ago': nan,
#  'customer_relation_type_last': 'active',
#  'customer_segment_changed': 'no',
#  'customer_segment_changed_measurements_ago': nan,
#  'customer_segment_last': 'individual',
#  'customer_type_changed': 'no',
#  'customer_type_changed_measurements_ago': nan,
#  'customer_type_last': 'primary',
#  'diff_first_contract_month_and_last_month': 11,
#  'diff_first_customer_month_and_first_contract_month': 3.0,
#  'diff_first_customer_month_and_last_month': 4.0,
#  'employment_index_changed': 'no',
#  'employment_index_changed_measurements_ago': nan,
#  'employment_index_last': 'not-employee',
#  'first_contract_month': 5,
#  'first_contract_months_ago': 1,
#  'gender': 'female',
#  'household_income_changed': 'no',
#  'household_income_changed_measurements_ago': nan,
#  'household_income_diff': 0.0,
#  'household_income_last': 311273.82000000001,
#  'ind_ahor_fin_ult1_changed': 'no',
#  'ind_ahor_fin_ult1_changed_measurements_ago': nan,
#  'ind_ahor_fin_ult1_last': nan,
#  'ind_ahor_fin_ult1_sum': nan,
#  'ind_aval_fin_ult1_changed': 'no',
#  'ind_aval_fin_ult1_changed_measurements_ago': nan,
#  'ind_aval_fin_ult1_last': nan,
#  'ind_aval_fin_ult1_sum': nan,
#  'ind_cco_fin_ult1_changed': 'no',
#  'ind_cco_fin_ult1_changed_measurements_ago': nan,
#  'ind_cco_fin_ult1_last': nan,
#  'ind_cco_fin_ult1_sum': nan,
#  'ind_cder_fin_ult1_changed': 'no',
#  'ind_cder_fin_ult1_changed_measurements_ago': nan,
#  'ind_cder_fin_ult1_last': nan,
#  'ind_cder_fin_ult1_sum': nan,
#  'ind_cno_fin_ult1_changed': 'no',
#  'ind_cno_fin_ult1_changed_measurements_ago': nan,
#  'ind_cno_fin_ult1_last': nan,
#  'ind_cno_fin_ult1_sum': nan,
#  'ind_ctju_fin_ult1_changed': 'no',
#  'ind_ctju_fin_ult1_changed_measurements_ago': nan,
#  'ind_ctju_fin_ult1_last': nan,
#  'ind_ctju_fin_ult1_sum': nan,
#  'ind_ctma_fin_ult1_changed': 'no',
#  'ind_ctma_fin_ult1_changed_measurements_ago': nan,
#  'ind_ctma_fin_ult1_last': nan,
#  'ind_ctma_fin_ult1_sum': nan,
#  'ind_ctop_fin_ult1_changed': 'no',
#  'ind_ctop_fin_ult1_changed_measurements_ago': nan,
#  'ind_ctop_fin_ult1_last': nan,
#  'ind_ctop_fin_ult1_sum': nan,
#  'ind_ctpp_fin_ult1_changed': 'no',
#  'ind_ctpp_fin_ult1_changed_measurements_ago': nan,
#  'ind_ctpp_fin_ult1_last': nan,
#  'ind_ctpp_fin_ult1_sum': nan,
#  'ind_deco_fin_ult1_changed': 'no',
#  'ind_deco_fin_ult1_changed_measurements_ago': nan,
#  'ind_deco_fin_ult1_last': nan,
#  'ind_deco_fin_ult1_sum': nan,
#  'ind_dela_fin_ult1_changed': 'no',
#  'ind_dela_fin_ult1_changed_measurements_ago': nan,
#  'ind_dela_fin_ult1_last': nan,
#  'ind_dela_fin_ult1_sum': nan,
#  'ind_deme_fin_ult1_changed': 'no',
#  'ind_deme_fin_ult1_changed_measurements_ago': nan,
#  'ind_deme_fin_ult1_last': nan,
#  'ind_deme_fin_ult1_sum': nan,
#  'ind_ecue_fin_ult1_changed': 'no',
#  'ind_ecue_fin_ult1_changed_measurements_ago': nan,
#  'ind_ecue_fin_ult1_last': nan,
#  'ind_ecue_fin_ult1_sum': nan,
#  'ind_fond_fin_ult1_changed': 'no',
#  'ind_fond_fin_ult1_changed_measurements_ago': nan,
#  'ind_fond_fin_ult1_last': nan,
#  'ind_fond_fin_ult1_sum': nan,
#  'ind_hip_fin_ult1_changed': 'no',
#  'ind_hip_fin_ult1_changed_measurements_ago': nan,
#  'ind_hip_fin_ult1_last': nan,
#  'ind_hip_fin_ult1_sum': nan,
#  'ind_nom_pens_ult1_changed': 'no',
#  'ind_nom_pens_ult1_changed_measurements_ago': nan,
#  'ind_nom_pens_ult1_last': nan,
#  'ind_nom_pens_ult1_sum': nan,
#  'ind_nomina_ult1_changed': 'no',
#  'ind_nomina_ult1_changed_measurements_ago': nan,
#  'ind_nomina_ult1_last': nan,
#  'ind_nomina_ult1_sum': nan,
#  'ind_plan_fin_ult1_changed': 'no',
#  'ind_plan_fin_ult1_changed_measurements_ago': nan,
#  'ind_plan_fin_ult1_last': nan,
#  'ind_plan_fin_ult1_sum': nan,
#  'ind_pres_fin_ult1_changed': 'no',
#  'ind_pres_fin_ult1_changed_measurements_ago': nan,
#  'ind_pres_fin_ult1_last': nan,
#  'ind_pres_fin_ult1_sum': nan,
#  'ind_reca_fin_ult1_changed': 'no',
#  'ind_reca_fin_ult1_changed_measurements_ago': nan,
#  'ind_reca_fin_ult1_last': nan,
#  'ind_reca_fin_ult1_sum': nan,
#  'ind_recibo_ult1_changed': 'no',
#  'ind_recibo_ult1_changed_measurements_ago': nan,
#  'ind_recibo_ult1_last': nan,
#  'ind_recibo_ult1_sum': nan,
#  'ind_tjcr_fin_ult1_changed': 'no',
#  'ind_tjcr_fin_ult1_changed_measurements_ago': nan,
#  'ind_tjcr_fin_ult1_last': nan,
#  'ind_tjcr_fin_ult1_sum': nan,
#  'ind_valo_fin_ult1_changed': 'no',
#  'ind_valo_fin_ult1_changed_measurements_ago': nan,
#  'ind_valo_fin_ult1_last': nan,
#  'ind_valo_fin_ult1_sum': nan,
#  'ind_viv_fin_ult1_changed': 'no',
#  'ind_viv_fin_ult1_changed_measurements_ago': nan,
#  'ind_viv_fin_ult1_last': nan,
#  'ind_viv_fin_ult1_sum': nan,
#  'is_active_customer_changed': 'no',
#  'is_active_customer_changed_measurements_ago': nan,
#  'is_active_customer_last': 'yes',
#  'is_dead': 'no',
#  'is_foreigner': 'no',
#  'is_new_customer_changed': 'no',
#  'is_new_customer_changed_measurements_ago': nan,
#  'is_new_customer_last': 'yes',
#  'is_primary_customer_changed': 'no',
#  'is_primary_customer_changed_measurements_ago': nan,
#  'is_primary_customer_last': 'yes',
#  'is_spouse_of_an_employee_changed': 'no',
#  'is_spouse_of_an_employee_changed_measurements_ago': nan,
#  'is_spouse_of_an_employee_last': nan,
#  'join_channel': 'KHK',
#  'measurement_month_last': 6,
#  'province_code_changed': 'no',
#  'province_code_changed_measurements_ago': nan,
#  'province_code_last': 'prov_28',
#  'target': nan}

# %%
pd.read_csv('agg_train_ind_viv_fin_ult1.csv').T
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-47-885634b712a3> in <module>()
# ----> 1 pd.read_csv('agg_train_ind_viv_fin_ult1.csv').T
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     560                     skip_blank_lines=skip_blank_lines)
#     561
# --> 562         return _read(filepath_or_buffer, kwds)
#     563
#     564     parser_f.__name__ = name
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     313
#     314     # Create the parser.
# --> 315     parser = TextFileReader(filepath_or_buffer, **kwds)
#     316
#     317     if (nrows is not None) and (chunksize is not None):
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     643             self.options['has_index_names'] = kwds['has_index_names']
#     644
# --> 645         self._make_engine(self.engine)
#     646
#     647     def close(self):
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     797     def _make_engine(self, engine='c'):
#     798         if engine == 'c':
# --> 799             self._engine = CParserWrapper(self.f, **self.options)
#     800         else:
#     801             if engine == 'python':
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1211         kwds['allow_leading_cols'] = self.index_col is not False
#    1212
# -> 1213         self._reader = _parser.TextReader(src, **kwds)
#    1214
#    1215         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3427)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:6861)()
#
# IOError: File agg_train_ind_viv_fin_ult1.csv does not exist
